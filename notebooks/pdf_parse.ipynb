# %%
from unstructured.partition.auto import partition

# %%
filename = 'dump/file6915_1.pdf'

# %%
elements = partition(filename=filename, strategy='hi-res')
# Out:
# [nltk_data] Downloading package punkt to /home/sawyer/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/sawyer/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.

# %%
elements

# %%
print("".join([str(el) for el in elements[:5]]))
# Out:
# d e z i r o h t u A e r u s o c s D clii lb u P
